# %%
from ultralytics import YOLO

# %%
model = YOLO("yolov8n.pt")
model.train(data="dataset/data.yaml", epochs=50, imgsz=384, batch=32, name="cuphead_entity_detector")
# Out:
# ...
# Ultralytics 8.3.227 🚀 Python-3.12.7 torch-2.9.0+cu128 CUDA:0 (NVIDIA RTX A1000 Laptop GPU, 4096MiB)
# ...

# %%
model = YOLO("yolo11n.pt")
model.train(data="dataset/data.yaml", epochs=50, imgsz=640, batch=32, name="cuphead_entity_detector")
# Out:
# Ultralytics 8.3.227 🚀 Python-3.12.7 torch-2.9.0+cu128 CUDA:0 (NVIDIA RTX A1000 Laptop GPU, 4096MiB)
# ...

# %%
model = YOLO("runs/detect/cuphead_entity_detector3/weights/best.pt")

model.export(
    format="onnx",
    opset=13,
    dynamic=True,
    simplify=True,
    imgsz=640,
    half=False,
    nms=False
)
# Out:
# Ultralytics 8.3.227 🚀 Python-3.12.7 torch-2.9.0+cu128 CPU (12th Gen Intel Core i9-12900H)
# YOLO11n summary (fused): 100 layers, 2,582,932 parameters, 0 gradients, 6.3 GFLOPs
#
# PyTorch: starting from 'runs/detect/cuphead_entity_detector3/weights/best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 8, 8400) (5.2 MB)
#
# ONNX: starting export with onnx 1.19.1 opset 13...
# ONNX: slimming with onnxslim 0.1.74...
# ONNX: export success ✅ 4.7s, saved as 'runs/detect/cuphead_entity_detector3/weights/best.onnx' (10.2 MB)
#
# Export complete (5.8s)
# Results saved to /mnt/c/Users/PC/Documents/Cuphead_Notebooks/combined_yolo/runs/detect/cuphead_entity_detector3/weights
# Predict:         yolo predict task=detect model=runs/detect/cuphead_entity_detector3/weights/best.onnx imgsz=640
# Validate:        yolo val task=detect model=runs/detect/cuphead_entity_detector3/weights/best.onnx imgsz=640 data=dataset/data.yaml
# Visualize:       https://netron.app
# ...
